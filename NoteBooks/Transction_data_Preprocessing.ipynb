# %%
import pandas as pd
import numpy as np

# %%
#sales_data = pd.read_csv(r"C:\Users\wwwsi\OneDrive\Documents\Project Brothers BBQ\Dataset _\Total_Monthly_Sales.csv")
Transction_data = pd.read_csv(r"C:\Users\wwwsi\OneDrive\Documents\Project Brothers BBQ\Dataset _\sales_transactions.csv")

# %%
Transction_data.head()
# Out:
#          date time_of_purchase customer_name    phone_number   age  \
# 0  2026-02-01            19:52     Kavya Raj  +91 7799371240   NaN
# 1  2026-02-01            20:31   Nithya Babu  +91 9120826773  33.0
# 2  2026-02-01            18:49       Kumar S  +91 8467854458  46.0
# 3  2026-02-01            21:26        Ravi K  +91 7054932966  47.0
# 4  2026-02-01            20:37  Meena Prasad  +91 6902294131  50.0
#
#    order_type           item_bought is_combo  quantity  item_price_total  \
# 0     Walk-in    Chicken Leg (2 pc)       No         1               130
# 1  Phone Call  Chicken Wings (5 pc)       No         1               130
# 2     Walk-in  Chicken Wings (5 pc)       No         1               130
# 3  Phone Call  Chicken Wings (5 pc)       No         2               260
# 4     Walk-in    Chicken Leg (2 pc)       No         1               130
#
#    coupon_code coupon_used  discount_amount  final_amount payment_method  \
# 0  karur_kalam          No                0           130           GPay
# 1  karur_kalam          No                0           130           GPay
# 2  karur_kalam          No                0           130           Card
# 3  karur_kalam          No                0           260        PhonePe
# 4  karur_kalam          No                0           130           GPay
#
#    rating                                             review
# 0     5.0                                                NaN
# 1     NaN      Wings semma crispy ah irundhuchu, thanks anna
# 2     3.0                                                NaN
# 3     5.0  Chicken leg romba soft ah vekachu irundhuchu, ...
# 4     5.0                   Very tasty and quick service too

# %%
Transction_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5238 entries, 0 to 5237
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5238 non-null   str
#  1   time_of_purchase  5238 non-null   str
#  2   customer_name     4916 non-null   str
#  3   phone_number      5238 non-null   str
#  4   age               4452 non-null   float64
#  5   order_type        5238 non-null   str
#  6   item_bought       5238 non-null   str
#  7   is_combo          5238 non-null   str
#  8   quantity          5238 non-null   int64
#  9   item_price_total  5238 non-null   int64
#  10  coupon_code       5238 non-null   str
#  11  coupon_used       5238 non-null   str
#  12  discount_amount   5238 non-null   int64
#  13  final_amount      5238 non-null   int64
#  14  payment_method    5088 non-null   str
#  15  rating            4177 non-null   float64
#  16  review            3496 non-null   str
# dtypes: float64(2), int64(4), str(11)
# memory usage: 695.8 KB

# %%
Transction_data['date'] = pd.to_datetime(Transction_data["date"],errors = 'coerce')
Transction_data['time_of_purchase'] = pd.to_datetime(Transction_data['time_of_purchase'],errors = 'coerce')
Transction_data['age'] = Transction_data['age'].astype("Int64")
Transction_data['Item_price_total'] = Transction_data['item_price_total'].astype("float64")
Transction_data['discount_amount'] = Transction_data['discount_amount'].astype("float64")
Transction_data['final_amount'] = Transction_data['final_amount'].astype("float64")
# Out:
# C:\Users\wwwsi\AppData\Local\Temp\ipykernel_2972\1337635768.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Transction_data['time_of_purchase'] = pd.to_datetime(Transction_data['time_of_purchase'],errors = 'coerce')

# %%
Transction_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5238 entries, 0 to 5237
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5238 non-null   datetime64[us]
#  1   time_of_purchase  5238 non-null   datetime64[us]
#  2   customer_name     4916 non-null   str
#  3   phone_number      5238 non-null   str
#  4   age               4452 non-null   Int64
#  5   order_type        5238 non-null   str
#  6   item_bought       5238 non-null   str
#  7   is_combo          5238 non-null   str
#  8   quantity          5238 non-null   int64
#  9   item_price_total  5238 non-null   int64
#  10  coupon_code       5238 non-null   str
#  11  coupon_used       5238 non-null   str
#  12  discount_amount   5238 non-null   float64
#  13  final_amount      5238 non-null   float64
#  14  payment_method    5088 non-null   str
#  15  rating            4177 non-null   float64
#  16  review            3496 non-null   str
#  17  Item_price_total  5238 non-null   float64
# dtypes: Int64(1), datetime64[us](2), float64(4), int64(2), str(9)
# memory usage: 741.8 KB

# %%
# Search for missing values
print(Transction_data.shape)
Transction_data.isnull().sum()
# Out:
# (5238, 18)
# date                   0
# time_of_purchase       0
# customer_name        322
# phone_number           0
# age                  786
# order_type             0
# item_bought            0
# is_combo               0
# quantity               0
# item_price_total       0
# coupon_code            0
# coupon_used            0
# discount_amount        0
# final_amount           0
# payment_method       150
# rating              1061
# review              1742
# Item_price_total       0
# dtype: int64
